# %%
# variabili e tipi
nome = "Luca"
anni = 25
print(f"Ciao, {nome}! Hai {anni} anni.")
# Out:
# Ciao, Luca! Hai 25 anni.

# %%
# liste, tuple, dict
numeri = [1,2,3,4,5]
quadrati = [n**2 for n in numeri]
info = {"nome": nome, "eta": anni}

# %%
# funzioni e condizionali
def pari(x): return x % 2 == 0
for n in numeri:
    print(n, "pari" if pari(n) else "dispari")
# Out:
# 1 dispari
# 2 pari
# 3 dispari
# 4 pari
# 5 dispari
